# %% [markdown]
# <a href="https://colab.research.google.com/github/KalpanadeviGunasekaran/Pandas-/blob/main/pandassp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([1,2,3,4,5])
a
print(a)
# Out:
# [1 2 3 4 5]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
n=pd.Series([1,2,3,4,5])
type(n)
n
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
n[3]
# Out:
# 4

# %%
n.drop(3,inplace=True)
n
# Out:
# 0    1
# 1    2
# 2    3
# 4    5
# dtype: int64

# %%
n.loc[4]#it shows the index 4 value in the series
# Out:
# 5

# %%
n.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
n.iloc[3]#it takes index itself in order and gives the value
# Out:
# 5

# %%
n=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
n
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
n.loc['a']
# Out:
# 1

# %%
data=[['anu',10,'2.3.4'],['ammu',None,None],['ammu',None,'4.5.6']]
data
# Out:
# [['anu', 10, '2.3.4'], ['ammu', None, None], ['ammu', None, '4.5.6']]

# %%
df=pd.DataFrame(data)
df
# Out:
#       0     1      2
# 0   anu  10.0  2.3.4
# 1  ammu   NaN   None
# 2  ammu   NaN  4.5.6

# %%
df[0][0]
# Out:
# 'anu'

# %%
df[1:2]
# Out:
#       0   1     2
# 1  ammu NaN  None

# %%
df=pd.DataFrame(data,index=["a","b","c"],columns=["name","age","dob"])
df
# Out:
#    name   age    dob
# a   anu  10.0  2.3.4
# b  ammu   NaN   None
# c  ammu   NaN  4.5.6

# %%
df['name']
# Out:
# a     anu
# b    ammu
# c    ammu
# Name: name, dtype: object

# %%
df['name']['a']
# Out:
# 'anu'

# %%
df.loc['a','name']
# Out:
# 'anu'

# %%
df.iloc[0,0]
# Out:
# 'anu'

# %%
df[0:1]
# Out:
#   name   age    dob
# a  anu  10.0  2.3.4

# %%
df[0:1]
# Out:
#   name   age    dob
# a  anu  10.0  2.3.4

# %%
n.plot()
# Out:
# <Axes: >

# %%
n.hist(bins=3)
# Out:
# <Axes: >

# %%
type(n)
# Out:
# pandas.core.series.Series

# %%
a=n.to_numpy()
type(a)
# Out:
# numpy.ndarray

# %%
df.head(2)
# Out:
#    name   age    dob
# a   anu  10.0  2.3.4
# b  ammu   NaN   None

# %%
df.tail(-2)
# Out:
#    name  age    dob
# c  ammu  NaN  4.5.6

# %%
#None,' ','','-','?','Nil',np.nan(not a number)

# %%
df.isnull().sum()
# Out:
# name    0
# age     2
# dob     1
# dtype: int64

# %%
df.isnull()
# Out:
#     name    age    dob
# a  False  False  False
# b  False   True   True
# c  False   True  False

# %%
df.count()#it counts but doesnot include null values
# Out:
# name    3
# age     1
# dob     2
# dtype: int64

# %%
df.isnull().count()#it counts and includes null values also
# Out:
# name    3
# age     3
# dob     3
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#   name   age    dob
# a  anu  10.0  2.3.4

# %%
df.drop(['age'],axis=1,inplace=True)#axis=0 row,axix=1 coloumn

# %%
df
# Out:
#   name    dob
# a  anu  2.3.4

# %%
df.drop(['a'],axis=0,inplace=True)

# %%
df=pd.DataFrame(data,index=["a","b","c"],columns=["name","age","dob"])
df
# Out:
#    name   age    dob
# a   anu  10.0  2.3.4
# b  ammu   NaN   None
# c  ammu   NaN  4.5.6

# %%
df.drop(['a','b'])
# Out:
#    name  age    dob
# c  ammu  NaN  4.5.6

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a>3
# Out:
# array([False, False, False,  True,  True])

# %%
a[a>3]
# Out:
# array([4, 5])

# %%
a[a%2==0]
# Out:
# array([2, 4])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     1 non-null      float64
#  2   dob     2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df['name'].str.contains('n')
# Out:
# a     True
# b    False
# c    False
# Name: name, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 3)
# 9
# [Index(['a', 'b', 'c'], dtype='object'), Index(['name', 'age', 'dob'], dtype='object')]
# 2
# name     object
# age     float64
# dob      object
# dtype: object
# Index(['a', 'b', 'c'], dtype='object')
# Index(['name', 'age', 'dob'], dtype='object')
# [['anu' 10.0 '2.3.4']
#  ['ammu' nan None]
#  ['ammu' nan '4.5.6']]

# %%
df1=df.copy()

# %%
df1
# Out:
#    name   age    dob
# a   anu  10.0  2.3.4
# b  ammu   NaN   None
# c  ammu   NaN  4.5.6

# %%
df1=df1.describe(include='all')#include null values
df1
# Out:
#         name   age    dob
# count      3   1.0      2
# unique     2   NaN      2
# top     ammu   NaN  2.3.4
# freq       2   NaN      1
# mean     NaN  10.0    NaN
# std      NaN   NaN    NaN
# min      NaN  10.0    NaN
# 25%      NaN  10.0    NaN
# 50%      NaN  10.0    NaN
# 75%      NaN  10.0    NaN
# max      NaN  10.0    NaN

# %%
df1=df1.describe()#does not include null values

# %%
df1
# Out:
#              age
# count   7.000000
# mean    8.714286
# std     3.401680
# min     1.000000
# 25%    10.000000
# 50%    10.000000
# 75%    10.000000
# max    10.000000

# %%
df.iloc[0][0]#using index by iloc
# Out:
# 'anu'

# %%
df.loc['a','name']#using col name and index name
# Out:
# 'anu'

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price=df.item_price.str.replace('$','')
df.head()
# Out:
# <ipython-input-41-42cd2b552eef>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# ...

# %%
df.item_name.unique
# Out:
# <bound method Series.unique of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object>

# %%
df.item_price=df.item_price.astype(float)

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
#df['item_price']*100;

# %%
df_drink=df[df.item_price > 5.0]
df_drink
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 8            4         1    Steak Soft Tacos
# 9            5         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...        9.25
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# ...

# %%
df_drink.item_name.nunique()
# Out:
# 44

# %%
df_drink.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Steak Burrito                            368
# Steak Bowl                               211
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# Chicken Crispy Tacos                      47
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        35
# Steak Salad Bowl                          29
# Barbacoa Soft Tacos                       25
# Chips and Guacamole                       24
# Veggie Salad Bowl                         18
# ...

# %%
df[df.item_name=='Carnitas Salad Bowl']
# Out:
#       order_id  quantity            item_name  \
# 1132       468         1  Carnitas Salad Bowl
# 1865       756         1  Carnitas Salad Bowl
# 2610      1035         1  Carnitas Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# 3749      1499         1  Carnitas Salad Bowl
# 4239      1692         1  Carnitas Salad Bowl
#
#                                      choice_description  item_price
# 1132  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       11.89
# 1865   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]        9.39
# 2610  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.89
# 3115  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...        9.39
# 3749  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.89
# 4239  [Tomatillo Green Chili Salsa, [Black Beans, Ch...       11.89

# %%
df[df.item_name=='Carnitas Salad Bowl'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Guacamole]]                                                  1
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]                                                              1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]    1
# [Tomatillo Green Chili Salsa, [Rice, Pinto Beans, Cheese, Sour Cream, Lettuce]]                               1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]    1
# [Tomatillo Green Chili Salsa, [Black Beans, Cheese, Guacamole]]                                               1
# Name: choice_description, dtype: int64

# %%
df[df.item_name=='Carnitas Salad Bowl'].choice_description.nunique()
# Out:
# 6

# %%
df.dropna(inplace=True)#to remove null values

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10)&(df.item_name=='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df[(df.item_price<10)&(df.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
s=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
s.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
s[(s.star_rating>8)&(s.content_rating=='PG-13')]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 25           8.6                                  Life Is Beautiful
# 26           8.6                       Once Upon a Time in the West
# 43           8.5                              The Dark Knight Rises
# 53           8.5                                       The Prestige
# 60           8.5                                           3 Idiots
# 69           8.4                                  Princess Mononoke
# ...

# %%
s[(s.star_rating>8)&(s.content_rating=='PG-13')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 232          8.1                                  Chungking Express
# 279          8.1                    The Perks of Being a Wallflower
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# 25           8.6                                  Life Is Beautiful
# 196          8.1                            Guardians of the Galaxy
# 180          8.2                                       Hotel Rwanda
# 73           8.4                            Jodaeiye Nader az Simin
# 260          8.1                                     The Sea Inside
# 118          8.3                 Indiana Jones and the Last Crusade
# ...

# %%
s[s.actors_list.str.contains('Daniel Radcliffe')]
# Out:
#      star_rating                                         title content_rating  \
# 222          8.1  Harry Potter and the Deathly Hallows: Part 2          PG-13
# 551          7.8      Harry Potter and the Prisoner of Azkaban             PG
# 642          7.7  Harry Potter and the Deathly Hallows: Part 1          PG-13
# 727          7.6           Harry Potter and the Goblet of Fire          PG-13
# 891          7.5        Harry Potter and the Half-Blood Prince             PG
# 909          7.5         Harry Potter and the Sorcerer's Stone             PG
# 932          7.4     Harry Potter and the Order of the Phoenix          PG-13
#
#          genre  duration                                        actors_list
# 222  Adventure       130  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 551  Adventure       142  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 642  Adventure       146  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# ...

# %%
s[s.actors_list.str.contains('Daniel Radcliffe')].sort_values(['duration'] and ['star_rating'])
# Out:
#      star_rating                                         title content_rating  \
# 932          7.4     Harry Potter and the Order of the Phoenix          PG-13
# 891          7.5        Harry Potter and the Half-Blood Prince             PG
# 909          7.5         Harry Potter and the Sorcerer's Stone             PG
# 727          7.6           Harry Potter and the Goblet of Fire          PG-13
# 642          7.7  Harry Potter and the Deathly Hallows: Part 1          PG-13
# 551          7.8      Harry Potter and the Prisoner of Azkaban             PG
# 222          8.1  Harry Potter and the Deathly Hallows: Part 2          PG-13
#
#          genre  duration                                        actors_list
# 932  Adventure       138  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 891  Adventure       153  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 909  Adventure       152  [u'Daniel Radcliffe', u'Rupert Grint', u'Richa...
# ...

# %%
s[s.actors_list.str.contains('Daniel Radcliffe')].sort_values(['duration'])
# Out:
#      star_rating                                         title content_rating  \
# 222          8.1  Harry Potter and the Deathly Hallows: Part 2          PG-13
# 932          7.4     Harry Potter and the Order of the Phoenix          PG-13
# 551          7.8      Harry Potter and the Prisoner of Azkaban             PG
# 642          7.7  Harry Potter and the Deathly Hallows: Part 1          PG-13
# 909          7.5         Harry Potter and the Sorcerer's Stone             PG
# 891          7.5        Harry Potter and the Half-Blood Prince             PG
# 727          7.6           Harry Potter and the Goblet of Fire          PG-13
#
#          genre  duration                                        actors_list
# 222  Adventure       130  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 932  Adventure       138  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 551  Adventure       142  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# ...

# %%
s[s.actors_list.str.contains('Daniel Radcliffe')].sort_values(['star_rating','duration'],ascending=[False,True])
# Out:
#      star_rating                                         title content_rating  \
# 222          8.1  Harry Potter and the Deathly Hallows: Part 2          PG-13
# 551          7.8      Harry Potter and the Prisoner of Azkaban             PG
# 642          7.7  Harry Potter and the Deathly Hallows: Part 1          PG-13
# 727          7.6           Harry Potter and the Goblet of Fire          PG-13
# 909          7.5         Harry Potter and the Sorcerer's Stone             PG
# 891          7.5        Harry Potter and the Half-Blood Prince             PG
# 932          7.4     Harry Potter and the Order of the Phoenix          PG-13
#
#          genre  duration                                        actors_list
# 222  Adventure       130  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 551  Adventure       142  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 642  Adventure       146  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# ...

# %%
k=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
k
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
k.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
k.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
k['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
k['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
r=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
r.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
r.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
r.beer_servings.min()
# Out:
# 0

# %%
r.beer_servings.max()
# Out:
# 376

# %%
r.beer_servings.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
r[r.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
r[r.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
r.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
r.groupby('continent').beer_servings.agg(['mean','max','min'])
# Out:
#                      mean  max  min
# continent
# Africa          61.471698  376    0
# Asia            37.045455  247    0
# Europe         193.777778  361    0
# North America  145.434783  285    1
# Oceania         89.687500  306    0
# South America  175.083333  333   93
